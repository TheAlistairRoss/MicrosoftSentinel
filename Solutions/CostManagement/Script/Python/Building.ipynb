# %%
import os
from datetime import datetime
import requests
import pandas as pd

# %%
services = ['Azure Monitor', 'Sentinel']
currencyCodes = ['USD', 'AUD', 'BRL', 'CAD', 'CHF', 'CNY', 'DKK', 'EUR', 'GBP', 'INR', 'JPY', 'KRW', 'NOK', 'NZD', 'RUB', 'SEK', 'TWD']
baseUrl = "https://prices.azure.com/api/retail/prices?api-version=2021-10-01-preview"

previousTier = {
    'Pay-as-you-go' : '',
    '100'  : 'Pay-as-you-go',
    '200'  : 100,
    '300'  : 200,
    '400'  : 300,
    '500'  : 400,
    '1000' : 500,
    '2000' : 1000,
    '5000' : 2000
}

filters = {
    'Azure Monitor' :"$filter=(serviceName eq 'Azure Monitor' or serviceName eq 'Log Analytics') and (meterName eq 'Pay-as-you-go Data Ingestion' or meterName eq '100 GB Commitment Tier Capacity Reservation' or meterName eq '200 GB Commitment Tier Capacity Reservation'  or meterName eq '300 GB Commitment Tier Capacity Reservation' or meterName eq '400 GB Commitment Tier Capacity Reservation' or meterName eq '500 GB Commitment Tier Capacity Reservation' or meterName eq '1000 GB Commitment Tier Capacity Reservation' or meterName eq '2000 GB Commitment Tier Capacity Reservation' or meterName eq '5000 GB Commitment Tier Capacity Reservation')",
    'Sentinel' : "$filter=(serviceName eq 'Sentinel') and (meterName eq 'Pay-as-you-go Analysis' or meterName eq '100 GB Commitment Tier Capacity Reservation' or meterName eq '200 GB Commitment Tier Capacity Reservation' or meterName eq '300 GB Commitment Tier Capacity Reservation' or meterName eq '400 GB Commitment Tier Capacity Reservation' or meterName eq '500 GB Commitment Tier Capacity Reservation' or meterName eq '1000 GB Commitment Tier Capacity Reservation' or meterName eq '2000 GB Commitment Tier Capacity Reservation' or meterName eq '5000 GB Commitment Tier Capacity Reservation')" 
}

# %%
class SentinelPricing:
    """This class represents the data from prices.azure.com for specific meters for Azure Monitor and Sentinel."""
    def __init__(self, time_generated, service_name: str, arm_region_name : str, currency_code : str, tier : str, unit_of_measure : str, retail_price : float, effective_start_date : str, effective_next_tier_gb: float = 0.0) -> None:
        self.time_generated = time_generated
        self.service_name = service_name
        self.arm_region_name = arm_region_name
        self.currency_code = currency_code
        self.tier = tier 
        self.unit_of_measure = unit_of_measure 
        self.retail_price = retail_price
        self.effective_start_date = effective_start_date
        self.effective_next_tier_gb = effective_next_tier_gb
        

        if tier == "Pay-as-you-go":
            self.effective_price_per_gb = float(retail_price)
        else:
            self.effective_price_per_gb = float(int(tier) / retail_price)
    
    def add_effective_next_tier_gb(self, previous_tier_effective_price_per_gb):
        self.effective_next_tier_gb = self.retail_price / previous_tier_effective_price_per_gb

    def __str__(self) -> str:
        return "{},{},{},{},{},{},{},{},{}".format(
            self.time_generated,
            self.service_name,
            self.arm_region_name,
            self.currency_code,
            self.tier,
            self.unit_of_measure,
            self.retail_price,
            self.effective_start_date,
            self.effective_next_tier_gb)

# %%
def get_sentinel_pricing (service=None, currency_code=None, time_generated=None):

    # Begin: Check Parameters
    if time_generated is None:
        time_generated = datetime.now().strftime('%Y/%m/%d %H:%M:%S')
        print(f'Parameters: service={service}, currencyCode={currency_code}, time_generated=(DefaultParam){time_generated}')
    else:
        print(f'Parameters: service={service}, currencyCode={currency_code}, time_generated={time_generated}')

    if service is None or currency_code is None:
        print(f'You must provide values to the "service" and "currency_code" parameters. Exiting')
        return

    starting_url = f"{baseUrl}&currencyCode={currency_code}&{filters[service]}"
    print(f'\nInitial URL: {starting_url}')

    items_returned = 0
    sentinel_price_list = []

    url = starting_url
    while True:
        response = requests.get(url)
        if response.status_code != 200:
            print("Error: Unable to fetch data")
            break

        data = response.json()
        items_returned += data['Count']

        # Create new instance of the SentinelPricing class and add them to the output list
        for dataItem in data['Items']:
            # Filter out 0 retail prices as we aren't interested in free trials / tiers
            if dataItem['retailPrice'] != 0:
                sentinel_price = SentinelPricing(
                    time_generated = time_generated,
                    service_name = service,
                    arm_region_name = dataItem['armRegionName'],
                    currency_code = currency_code,
                    tier = dataItem['meterName'].split()[0],
                    unit_of_measure = dataItem['unitOfMeasure'],
                    retail_price = dataItem['retailPrice'],
                    effective_start_date = dataItem['effectiveStartDate']
                )

                sentinel_price_list.append(sentinel_price)

        # Determine if there is a next link, if not break the loop
        if data['NextPageLink']:
            url = data['NextPageLink']
        elif data['Count'] == 100:
            url = f'{starting_url}&$skip={items_returned}'
        else:
            break
    
    for x in sentinel_price_list
    
    sentinel_price_list_sorted = sorted(sentinel_price_list, key=lambda x: (x.arm_region_name, x.retail_price))
    
    print(f'Total items_returned: {len(sentinel_price_list)}')
    return sentinel_price_list_sorted

# %%
sentinel_price = SentinelPricing(
    time_generated = '13/03/2023 17:46:36',
    service_name = 'Sentinel',
    arm_region_name = 'westus',
    currency_code = 'USD',
    tier = 'Pay-as-you-go',
    unit_of_measure = '1 GB',
    retail_price = '2.6',
    effective_start_date = '24/09/2019 00:00:00')

# %%
print(sentinel_price)
# Out:
# 13/03/2023 17:46:36,Sentinel,westus,USD,Pay-as-you-go,1 GB,2.6,24/09/2019 00:00:00,0.0

# %%
service = "Azure Monitor"
currency_code = "USD"
time_generated = datetime.now().strftime('%Y/%m/%d %H:%M:%S')
sentinel_prices = get_sentinel_pricing(service, currency_code, time_generated)
# Out:
# Parameters: service=Azure Monitor, currencyCode=USD, time_generated=2023/03/14 18:00:33
#
# Initial URL: https://prices.azure.com/api/retail/prices?api-version=2021-10-01-preview&currencyCode=USD&$filter=(serviceName eq 'Azure Monitor' or serviceName eq 'Log Analytics') and (meterName eq 'Pay-as-you-go Data Ingestion' or meterName eq '100 GB Commitment Tier Capacity Reservation' or meterName eq '200 GB Commitment Tier Capacity Reservation'  or meterName eq '300 GB Commitment Tier Capacity Reservation' or meterName eq '400 GB Commitment Tier Capacity Reservation' or meterName eq '500 GB Commitment Tier Capacity Reservation' or meterName eq '1000 GB Commitment Tier Capacity Reservation' or meterName eq '2000 GB Commitment Tier Capacity Reservation' or meterName eq '5000 GB Commitment Tier Capacity Reservation')
# Total items_returned: 512

# %%
for i in sentinel_prices:
    print(i)
# Out:
# 2023/03/14 18:00:33,Azure Monitor,Global,USD,Pay-as-you-go,1 GB,2.3,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,attatlanta1,USD,100,1/Day,196.0,2022-04-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,attatlanta1,USD,200,1/Day,368.0,2022-04-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,attatlanta1,USD,300,1/Day,540.0,2022-04-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,attatlanta1,USD,400,1/Day,704.0,2022-04-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,attatlanta1,USD,500,1/Day,865.0,2022-04-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,attatlanta1,USD,1000,1/Day,1700.0,2022-04-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,attatlanta1,USD,2000,1/Day,3320.0,2022-04-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,attatlanta1,USD,5000,1/Day,8050.0,2022-04-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,attdallas1,USD,100,1/Day,219.52,2022-04-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,attdallas1,USD,200,1/Day,412.16,2022-04-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,attdallas1,USD,300,1/Day,604.8,2022-04-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,attdallas1,USD,400,1/Day,788.48,2022-04-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,attdallas1,USD,500,1/Day,968.8,2022-04-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,attdallas1,USD,1000,1/Day,1904.0,2022-04-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,attdallas1,USD,2000,1/Day,3718.4,2022-04-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,attdallas1,USD,5000,1/Day,9016.0,2022-04-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiacentral,USD,Pay-as-you-go,1 GB,3.34,2020-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiacentral,USD,100,1/Day,274.4,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiacentral,USD,200,1/Day,515.2,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiacentral,USD,300,1/Day,756.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiacentral,USD,400,1/Day,985.6,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiacentral,USD,500,1/Day,1211.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiacentral,USD,1000,1/Day,2380.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiacentral,USD,2000,1/Day,4648.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiacentral,USD,5000,1/Day,11270.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiacentral2,USD,Pay-as-you-go,1 GB,3.34,2020-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiacentral2,USD,100,1/Day,284.2,2020-09-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiacentral2,USD,200,1/Day,533.6,2020-09-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiacentral2,USD,300,1/Day,783.0,2020-09-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiacentral2,USD,400,1/Day,1020.8,2020-09-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiacentral2,USD,500,1/Day,1254.25,2020-09-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiacentral2,USD,1000,1/Day,2465.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiacentral2,USD,2000,1/Day,4814.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiacentral2,USD,5000,1/Day,11672.5,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiaeast,USD,Pay-as-you-go,1 GB,3.34,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiaeast,USD,100,1/Day,274.4,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiaeast,USD,200,1/Day,515.2,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiaeast,USD,300,1/Day,756.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiaeast,USD,400,1/Day,985.6,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiaeast,USD,500,1/Day,1211.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiaeast,USD,1000,1/Day,2380.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiaeast,USD,2000,1/Day,4648.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiaeast,USD,5000,1/Day,11270.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiasoutheast,USD,Pay-as-you-go,1 GB,3.34,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiasoutheast,USD,100,1/Day,274.4,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiasoutheast,USD,200,1/Day,515.2,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiasoutheast,USD,300,1/Day,756.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiasoutheast,USD,400,1/Day,985.6,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiasoutheast,USD,500,1/Day,1211.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiasoutheast,USD,1000,1/Day,2380.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiasoutheast,USD,2000,1/Day,4648.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,australiasoutheast,USD,5000,1/Day,11270.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,brazilsouth,USD,Pay-as-you-go,1 GB,4.6,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,brazilsouth,USD,100,1/Day,392.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,brazilsouth,USD,200,1/Day,736.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,brazilsouth,USD,300,1/Day,1080.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,brazilsouth,USD,400,1/Day,1408.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,brazilsouth,USD,500,1/Day,1730.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,brazilsouth,USD,1000,1/Day,3400.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,brazilsouth,USD,2000,1/Day,6640.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,brazilsouth,USD,5000,1/Day,16100.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,brazilsoutheast,USD,Pay-as-you-go,1 GB,5.29,2020-09-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,brazilsoutheast,USD,100,1/Day,450.8,2020-10-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,brazilsoutheast,USD,200,1/Day,846.4,2020-10-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,brazilsoutheast,USD,300,1/Day,1242.0,2020-10-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,brazilsoutheast,USD,400,1/Day,1619.2,2020-10-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,brazilsoutheast,USD,500,1/Day,1989.5,2020-10-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,brazilsoutheast,USD,1000,1/Day,3910.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,brazilsoutheast,USD,2000,1/Day,7636.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,brazilsoutheast,USD,5000,1/Day,18515.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,canadacentral,USD,Pay-as-you-go,1 GB,2.76,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,canadacentral,USD,100,1/Day,219.52,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,canadacentral,USD,200,1/Day,412.16,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,canadacentral,USD,300,1/Day,604.8,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,canadacentral,USD,400,1/Day,788.48,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,canadacentral,USD,500,1/Day,968.8,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,canadacentral,USD,1000,1/Day,1904.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,canadacentral,USD,2000,1/Day,3718.4,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,canadacentral,USD,5000,1/Day,9016.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,canadaeast,USD,Pay-as-you-go,1 GB,2.76,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,canadaeast,USD,100,1/Day,219.52,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,canadaeast,USD,200,1/Day,412.16,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,canadaeast,USD,300,1/Day,604.8,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,canadaeast,USD,400,1/Day,788.48,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,canadaeast,USD,500,1/Day,968.8,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,canadaeast,USD,1000,1/Day,1904.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,canadaeast,USD,2000,1/Day,3718.4,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,canadaeast,USD,5000,1/Day,9016.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,centralindia,USD,Pay-as-you-go,1 GB,3.22,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,centralindia,USD,100,1/Day,274.4,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,centralindia,USD,200,1/Day,515.2,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,centralindia,USD,300,1/Day,756.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,centralindia,USD,400,1/Day,985.6,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,centralindia,USD,500,1/Day,1211.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,centralindia,USD,1000,1/Day,2380.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,centralindia,USD,2000,1/Day,4648.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,centralindia,USD,5000,1/Day,11270.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,centralus,USD,Pay-as-you-go,1 GB,2.76,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,centralus,USD,100,1/Day,219.52,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,centralus,USD,200,1/Day,412.16,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,centralus,USD,300,1/Day,604.8,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,centralus,USD,400,1/Day,788.48,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,centralus,USD,500,1/Day,968.8,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,centralus,USD,1000,1/Day,1904.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,centralus,USD,2000,1/Day,3718.4,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,centralus,USD,5000,1/Day,9016.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastasia,USD,Pay-as-you-go,1 GB,4.03,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastasia,USD,100,1/Day,303.8,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastasia,USD,200,1/Day,570.4,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastasia,USD,300,1/Day,837.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastasia,USD,400,1/Day,1091.2,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastasia,USD,500,1/Day,1340.75,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastasia,USD,1000,1/Day,2635.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastasia,USD,2000,1/Day,5146.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastasia,USD,5000,1/Day,12477.5,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastus,USD,Pay-as-you-go,1 GB,2.3,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastus,USD,100,1/Day,196.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastus,USD,200,1/Day,368.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastus,USD,300,1/Day,540.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastus,USD,400,1/Day,704.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastus,USD,500,1/Day,865.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastus,USD,1000,1/Day,1700.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastus,USD,2000,1/Day,3320.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastus,USD,5000,1/Day,8050.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastus2,USD,Pay-as-you-go,1 GB,2.76,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastus2,USD,100,1/Day,196.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastus2,USD,200,1/Day,368.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastus2,USD,300,1/Day,540.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastus2,USD,400,1/Day,704.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastus2,USD,500,1/Day,865.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastus2,USD,1000,1/Day,1700.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastus2,USD,2000,1/Day,3320.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,eastus2,USD,5000,1/Day,8050.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,francecentral,USD,Pay-as-you-go,1 GB,2.76,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,francecentral,USD,100,1/Day,245.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,francecentral,USD,200,1/Day,460.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,francecentral,USD,300,1/Day,675.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,francecentral,USD,400,1/Day,880.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,francecentral,USD,500,1/Day,1081.25,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,francecentral,USD,1000,1/Day,2125.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,francecentral,USD,2000,1/Day,4150.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,francecentral,USD,5000,1/Day,10062.5,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,francesouth,USD,Pay-as-you-go,1 GB,2.76,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,francesouth,USD,100,1/Day,252.84,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,francesouth,USD,200,1/Day,474.72,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,francesouth,USD,300,1/Day,696.6,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,francesouth,USD,400,1/Day,908.16,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,francesouth,USD,500,1/Day,1115.85,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,francesouth,USD,1000,1/Day,2193.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,francesouth,USD,2000,1/Day,4282.8,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,francesouth,USD,5000,1/Day,10384.5,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,germanynorth,USD,Pay-as-you-go,1 GB,3.887,2019-09-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,germanynorth,USD,100,1/Day,272.44,2023-03-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,germanynorth,USD,200,1/Day,511.52,2023-03-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,germanynorth,USD,300,1/Day,750.6,2023-03-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,germanynorth,USD,400,1/Day,978.56,2023-03-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,germanynorth,USD,500,1/Day,1202.35,2023-03-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,germanynorth,USD,1000,1/Day,2363.0,2023-03-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,germanynorth,USD,2000,1/Day,4614.8,2023-03-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,germanynorth,USD,5000,1/Day,11189.5,2023-03-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,germanywestcentral,USD,Pay-as-you-go,1 GB,2.99,2019-09-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,germanywestcentral,USD,100,1/Day,252.84,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,germanywestcentral,USD,200,1/Day,474.72,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,germanywestcentral,USD,300,1/Day,696.6,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,germanywestcentral,USD,400,1/Day,908.16,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,germanywestcentral,USD,500,1/Day,1115.85,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,germanywestcentral,USD,1000,1/Day,2193.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,germanywestcentral,USD,2000,1/Day,4282.8,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,germanywestcentral,USD,5000,1/Day,10384.5,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,japaneast,USD,Pay-as-you-go,1 GB,3.34,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,japaneast,USD,100,1/Day,284.2,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,japaneast,USD,200,1/Day,533.6,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,japaneast,USD,300,1/Day,783.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,japaneast,USD,400,1/Day,1020.8,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,japaneast,USD,500,1/Day,1254.25,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,japaneast,USD,1000,1/Day,2465.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,japaneast,USD,2000,1/Day,4814.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,japaneast,USD,5000,1/Day,11672.5,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,japanwest,USD,Pay-as-you-go,1 GB,3.57,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,japanwest,USD,100,1/Day,303.8,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,japanwest,USD,200,1/Day,570.4,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,japanwest,USD,300,1/Day,837.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,japanwest,USD,400,1/Day,1091.2,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,japanwest,USD,500,1/Day,1340.75,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,japanwest,USD,1000,1/Day,2635.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,japanwest,USD,2000,1/Day,5146.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,japanwest,USD,5000,1/Day,12477.5,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,jioindiacentral,USD,Pay-as-you-go,1 GB,3.22,2021-08-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,jioindiacentral,USD,100,1/Day,274.4,2021-08-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,jioindiacentral,USD,200,1/Day,515.2,2021-08-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,jioindiacentral,USD,300,1/Day,756.0,2021-08-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,jioindiacentral,USD,400,1/Day,985.6,2021-08-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,jioindiacentral,USD,500,1/Day,1211.0,2021-08-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,jioindiacentral,USD,1000,1/Day,2380.0,2021-08-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,jioindiacentral,USD,2000,1/Day,4648.0,2021-08-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,jioindiacentral,USD,5000,1/Day,11270.0,2021-08-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,jioindiawest,USD,Pay-as-you-go,1 GB,3.22,2021-04-15T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,jioindiawest,USD,100,1/Day,274.4,2021-04-15T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,jioindiawest,USD,200,1/Day,515.2,2021-04-15T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,jioindiawest,USD,300,1/Day,756.0,2021-04-15T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,jioindiawest,USD,400,1/Day,985.6,2021-04-15T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,jioindiawest,USD,500,1/Day,1211.0,2021-04-15T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,koreacentral,USD,Pay-as-you-go,1 GB,3.11,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,koreacentral,USD,100,1/Day,264.6,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,koreacentral,USD,200,1/Day,496.8,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,koreacentral,USD,300,1/Day,729.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,koreacentral,USD,400,1/Day,950.4,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,koreacentral,USD,500,1/Day,1167.75,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,koreacentral,USD,1000,1/Day,2295.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,koreacentral,USD,2000,1/Day,4482.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,koreacentral,USD,5000,1/Day,10867.5,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,koreasouth,USD,Pay-as-you-go,1 GB,3.11,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,koreasouth,USD,100,1/Day,245.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,koreasouth,USD,200,1/Day,460.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,koreasouth,USD,300,1/Day,675.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,koreasouth,USD,400,1/Day,880.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,koreasouth,USD,500,1/Day,1081.25,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,koreasouth,USD,1000,1/Day,2125.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,koreasouth,USD,2000,1/Day,4150.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,koreasouth,USD,5000,1/Day,10062.5,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,northcentralus,USD,Pay-as-you-go,1 GB,2.76,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,northcentralus,USD,100,1/Day,219.52,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,northcentralus,USD,200,1/Day,412.16,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,northcentralus,USD,300,1/Day,604.8,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,northcentralus,USD,400,1/Day,788.48,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,northcentralus,USD,500,1/Day,968.8,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,northcentralus,USD,1000,1/Day,1904.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,northcentralus,USD,2000,1/Day,3718.4,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,northcentralus,USD,5000,1/Day,9016.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,northeurope,USD,Pay-as-you-go,1 GB,2.76,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,northeurope,USD,100,1/Day,235.2,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,northeurope,USD,200,1/Day,441.6,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,northeurope,USD,300,1/Day,648.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,northeurope,USD,400,1/Day,844.8,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,northeurope,USD,500,1/Day,1038.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,northeurope,USD,1000,1/Day,2040.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,northeurope,USD,2000,1/Day,3984.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,northeurope,USD,5000,1/Day,9660.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,norwayeast,USD,Pay-as-you-go,1 GB,3.289,2020-10-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,norwayeast,USD,100,1/Day,280.28,2020-10-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,norwayeast,USD,200,1/Day,526.24,2020-10-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,norwayeast,USD,300,1/Day,772.2,2020-10-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,norwayeast,USD,400,1/Day,1006.72,2020-10-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,norwayeast,USD,500,1/Day,1236.95,2020-10-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,norwayeast,USD,1000,1/Day,2431.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,norwayeast,USD,2000,1/Day,4747.6,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,norwayeast,USD,5000,1/Day,11511.5,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,norwaywest,USD,Pay-as-you-go,1 GB,4.276,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,norwaywest,USD,100,1/Day,364.36,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,norwaywest,USD,200,1/Day,684.11,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,norwaywest,USD,300,1/Day,1003.86,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,norwaywest,USD,400,1/Day,1308.74,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,norwaywest,USD,500,1/Day,1608.04,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,norwaywest,USD,1000,1/Day,3160.3,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,norwaywest,USD,2000,1/Day,6171.88,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,norwaywest,USD,5000,1/Day,14964.95,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,polandcentral,USD,Pay-as-you-go,1 GB,3.289,2023-02-21T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,polandcentral,USD,100,1/Day,278.124,2023-02-21T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,polandcentral,USD,200,1/Day,522.192,2023-02-21T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,polandcentral,USD,300,1/Day,766.26,2023-02-21T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,polandcentral,USD,400,1/Day,998.976,2023-02-21T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,polandcentral,USD,500,1/Day,1227.435,2023-02-21T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,polandcentral,USD,1000,1/Day,2412.3,2023-02-21T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,polandcentral,USD,2000,1/Day,4711.08,2023-02-21T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,polandcentral,USD,5000,1/Day,11422.95,2023-02-21T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,qatarcentral,USD,Pay-as-you-go,1 GB,3.29,2022-07-05T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,qatarcentral,USD,100,1/Day,252.84,2022-07-05T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,qatarcentral,USD,200,1/Day,474.72,2022-07-05T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,qatarcentral,USD,300,1/Day,696.6,2022-07-05T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,qatarcentral,USD,400,1/Day,908.16,2022-07-05T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,qatarcentral,USD,500,1/Day,1115.85,2022-07-05T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,qatarcentral,USD,1000,1/Day,2193.0,2022-07-05T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,qatarcentral,USD,2000,1/Day,4282.8,2022-07-05T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,qatarcentral,USD,5000,1/Day,10384.5,2022-07-05T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southafricanorth,USD,Pay-as-you-go,1 GB,3.36,2019-08-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southafricanorth,USD,100,1/Day,252.84,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southafricanorth,USD,200,1/Day,474.72,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southafricanorth,USD,300,1/Day,696.6,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southafricanorth,USD,400,1/Day,908.16,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southafricanorth,USD,500,1/Day,1115.85,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southafricanorth,USD,1000,1/Day,2193.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southafricanorth,USD,2000,1/Day,4282.8,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southafricanorth,USD,5000,1/Day,10384.5,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southafricawest,USD,Pay-as-you-go,1 GB,3.68,2020-10-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southafricawest,USD,100,1/Day,313.6,2020-10-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southafricawest,USD,200,1/Day,588.8,2020-10-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southafricawest,USD,300,1/Day,864.0,2020-10-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southafricawest,USD,400,1/Day,1126.4,2020-10-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southafricawest,USD,500,1/Day,1384.0,2020-10-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southafricawest,USD,1000,1/Day,2720.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southafricawest,USD,2000,1/Day,5312.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southafricawest,USD,5000,1/Day,12880.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southcentralus,USD,Pay-as-you-go,1 GB,2.76,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southcentralus,USD,100,1/Day,219.52,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southcentralus,USD,200,1/Day,412.16,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southcentralus,USD,300,1/Day,604.8,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southcentralus,USD,400,1/Day,788.48,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southcentralus,USD,500,1/Day,968.8,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southcentralus,USD,1000,1/Day,1904.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southcentralus,USD,2000,1/Day,3718.4,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southcentralus,USD,5000,1/Day,9016.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southeastasia,USD,Pay-as-you-go,1 GB,2.99,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southeastasia,USD,100,1/Day,254.8,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southeastasia,USD,200,1/Day,478.4,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southeastasia,USD,300,1/Day,702.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southeastasia,USD,400,1/Day,915.2,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southeastasia,USD,500,1/Day,1124.5,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southeastasia,USD,1000,1/Day,2210.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southeastasia,USD,2000,1/Day,4316.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southeastasia,USD,5000,1/Day,10465.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southindia,USD,Pay-as-you-go,1 GB,3.45,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southindia,USD,100,1/Day,295.96,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southindia,USD,200,1/Day,555.68,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southindia,USD,300,1/Day,815.4,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southindia,USD,400,1/Day,1063.04,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southindia,USD,500,1/Day,1306.15,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southindia,USD,1000,1/Day,2567.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southindia,USD,2000,1/Day,5013.2,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,southindia,USD,5000,1/Day,12155.5,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,swedencentral,USD,Pay-as-you-go,1 GB,2.99,2021-06-08T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,swedencentral,USD,100,1/Day,252.84,2021-10-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,swedencentral,USD,200,1/Day,474.72,2021-10-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,swedencentral,USD,300,1/Day,696.6,2021-10-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,swedencentral,USD,400,1/Day,908.16,2021-10-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,swedencentral,USD,500,1/Day,1115.85,2021-10-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,swedencentral,USD,1000,1/Day,2193.0,2021-06-08T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,swedencentral,USD,2000,1/Day,4282.8,2021-06-08T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,swedencentral,USD,5000,1/Day,10384.5,2021-06-08T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,swedensouth,USD,Pay-as-you-go,1 GB,2.99,2021-08-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,swedensouth,USD,100,1/Day,328.5,2021-08-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,swedensouth,USD,200,1/Day,616.77,2021-08-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,swedensouth,USD,300,1/Day,905.04,2021-08-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,swedensouth,USD,400,1/Day,1179.9,2021-08-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,swedensouth,USD,500,1/Day,1449.74,2021-08-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,swedensouth,USD,1000,1/Day,2849.2,2021-06-08T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,swedensouth,USD,2000,1/Day,5564.32,2021-06-08T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,swedensouth,USD,5000,1/Day,13491.8,2021-06-08T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,switzerlandnorth,USD,Pay-as-you-go,1 GB,3.289,2021-10-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,switzerlandnorth,USD,100,1/Day,252.84,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,switzerlandnorth,USD,200,1/Day,474.72,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,switzerlandnorth,USD,300,1/Day,696.6,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,switzerlandnorth,USD,400,1/Day,908.16,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,switzerlandnorth,USD,500,1/Day,1115.85,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,switzerlandnorth,USD,1000,1/Day,2193.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,switzerlandnorth,USD,2000,1/Day,4282.8,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,switzerlandnorth,USD,5000,1/Day,10384.5,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,switzerlandwest,USD,Pay-as-you-go,1 GB,4.27533,2021-10-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,switzerlandwest,USD,100,1/Day,252.84,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,switzerlandwest,USD,200,1/Day,474.72,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,switzerlandwest,USD,300,1/Day,696.6,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,switzerlandwest,USD,400,1/Day,908.16,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,switzerlandwest,USD,500,1/Day,1115.85,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,switzerlandwest,USD,1000,1/Day,2193.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,switzerlandwest,USD,2000,1/Day,4282.8,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,switzerlandwest,USD,5000,1/Day,10384.5,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uaecentral,USD,Pay-as-you-go,1 GB,3.956,2020-09-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uaecentral,USD,100,1/Day,337.12,2020-09-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uaecentral,USD,200,1/Day,632.96,2020-09-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uaecentral,USD,300,1/Day,928.8,2020-09-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uaecentral,USD,400,1/Day,1210.88,2020-09-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uaecentral,USD,500,1/Day,1487.8,2020-09-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uaecentral,USD,1000,1/Day,2924.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uaecentral,USD,2000,1/Day,5710.4,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uaecentral,USD,5000,1/Day,13846.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uaenorth,USD,Pay-as-you-go,1 GB,3.29,2019-01-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uaenorth,USD,100,1/Day,252.84,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uaenorth,USD,200,1/Day,474.72,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uaenorth,USD,300,1/Day,696.6,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uaenorth,USD,400,1/Day,908.16,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uaenorth,USD,500,1/Day,1115.85,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uaenorth,USD,1000,1/Day,2193.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uaenorth,USD,2000,1/Day,4282.8,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uaenorth,USD,5000,1/Day,10384.5,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uksouth,USD,Pay-as-you-go,1 GB,2.88,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uksouth,USD,100,1/Day,245.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uksouth,USD,200,1/Day,460.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uksouth,USD,300,1/Day,675.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uksouth,USD,400,1/Day,880.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uksouth,USD,500,1/Day,1081.25,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uksouth,USD,1000,1/Day,2125.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uksouth,USD,2000,1/Day,4150.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,uksouth,USD,5000,1/Day,10062.5,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,ukwest,USD,Pay-as-you-go,1 GB,2.88,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,ukwest,USD,100,1/Day,252.84,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,ukwest,USD,200,1/Day,474.72,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,ukwest,USD,300,1/Day,696.6,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,ukwest,USD,400,1/Day,908.16,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,ukwest,USD,500,1/Day,1115.85,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,ukwest,USD,1000,1/Day,2193.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,ukwest,USD,2000,1/Day,4282.8,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,ukwest,USD,5000,1/Day,10384.5,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,usgovarizona,USD,Pay-as-you-go,1 GB,2.875,2020-03-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,usgovarizona,USD,100,1/Day,245.0,2020-03-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,usgovarizona,USD,200,1/Day,460.0,2020-03-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,usgovarizona,USD,300,1/Day,675.0,2020-03-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,usgovarizona,USD,400,1/Day,880.0,2020-03-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,usgovarizona,USD,500,1/Day,1081.25,2020-03-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,usgovarizona,USD,1000,1/Day,2125.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,usgovarizona,USD,2000,1/Day,4150.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,usgovarizona,USD,5000,1/Day,10062.5,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,usgovvirginia,USD,Pay-as-you-go,1 GB,2.88,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,usgovvirginia,USD,100,1/Day,245.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,usgovvirginia,USD,200,1/Day,460.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,usgovvirginia,USD,300,1/Day,675.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,usgovvirginia,USD,400,1/Day,880.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,usgovvirginia,USD,500,1/Day,1081.25,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,usgovvirginia,USD,1000,1/Day,2125.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,usgovvirginia,USD,2000,1/Day,4150.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,usgovvirginia,USD,5000,1/Day,10062.5,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westcentralus,USD,Pay-as-you-go,1 GB,2.76,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westcentralus,USD,100,1/Day,219.52,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westcentralus,USD,200,1/Day,412.16,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westcentralus,USD,300,1/Day,604.8,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westcentralus,USD,400,1/Day,788.48,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westcentralus,USD,500,1/Day,968.8,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westcentralus,USD,1000,1/Day,1904.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westcentralus,USD,2000,1/Day,3718.4,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westcentralus,USD,5000,1/Day,9016.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westeurope,USD,Pay-as-you-go,1 GB,2.99,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westeurope,USD,100,1/Day,252.84,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westeurope,USD,200,1/Day,474.72,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westeurope,USD,300,1/Day,696.6,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westeurope,USD,400,1/Day,908.16,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westeurope,USD,500,1/Day,1115.85,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westeurope,USD,1000,1/Day,2193.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westeurope,USD,2000,1/Day,4282.8,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westeurope,USD,5000,1/Day,10384.5,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westindia,USD,Pay-as-you-go,1 GB,3.45,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westindia,USD,100,1/Day,270.48,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westindia,USD,200,1/Day,507.84,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westindia,USD,300,1/Day,745.2,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westindia,USD,400,1/Day,971.52,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westindia,USD,500,1/Day,1193.7,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westindia,USD,1000,1/Day,2346.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westindia,USD,2000,1/Day,4581.6,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westindia,USD,5000,1/Day,11109.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus,USD,Pay-as-you-go,1 GB,2.99,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus,USD,100,1/Day,219.52,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus,USD,200,1/Day,412.16,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus,USD,300,1/Day,604.8,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus,USD,400,1/Day,788.48,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus,USD,500,1/Day,968.8,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus,USD,1000,1/Day,1904.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus,USD,2000,1/Day,3718.4,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus,USD,5000,1/Day,9016.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus2,USD,Pay-as-you-go,1 GB,2.3,2018-02-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus2,USD,100,1/Day,196.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus2,USD,200,1/Day,368.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus2,USD,300,1/Day,540.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus2,USD,400,1/Day,704.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus2,USD,500,1/Day,865.0,2019-11-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus2,USD,1000,1/Day,1700.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus2,USD,2000,1/Day,3320.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus2,USD,5000,1/Day,8050.0,2021-06-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus3,USD,Pay-as-you-go,1 GB,2.3,2022-08-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus3,USD,100,1/Day,196.0,2022-08-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus3,USD,200,1/Day,368.0,2022-08-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus3,USD,300,1/Day,540.0,2022-08-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus3,USD,400,1/Day,704.0,2022-08-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus3,USD,500,1/Day,865.0,2022-08-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus3,USD,1000,1/Day,1700.0,2022-08-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus3,USD,2000,1/Day,3320.0,2022-08-01T00:00:00Z,0.0
# 2023/03/14 18:00:33,Azure Monitor,westus3,USD,5000,1/Day,8050.0,2022-08-01T00:00:00Z,0.0

# %%
for obj in sentinel_prices[0:3]:
    current_tier = obj.tier
    previous_tier = previousTier.get(current_tier)

    print("currentTierType = {}, currentTierValue = {}".format(type(current_tier),current_tier))
    print("previousTierType = {}, previousTierValue = {}".format(type(previous_tier),previous_tier))
    
    armRegionTest = [x for x in sentinel_prices if x.arm_region_name == obj.arm_region_name]
    tierTest = [x for x in sentinel_prices if x.tier == previous_tier]
    print("ARMTest: {}".format(armRegionTest))
    print("TierTest: {}".format(tierTest))

    #previous_tier_obj = [x for x in sentinel_prices if x.arm_region_name == obj.arm_region_name and x.tier == previous_tier]

    #print(previous_tier_obj)
    #if len(previous_tier_obj) > 1:
    #    print("Warning: Multiple objects returned when determining previous tier")

    #if len(previous_tier_obj) > 0:
    #    previous_tier_obj = previous_tier_obj[0]
    #    obj.add_effective_next_tier_gb(previous_tier_obj.effective_price_per_gb)
    #    print(obj.effective_next_tier_gb)
    #else:
    #    print(f"Length = {len(previous_tier_obj)}")
# Out:
# currentTierType = <class 'str'>, currentTierValue = Pay-as-you-go
# previousTierType = <class 'str'>, previousTierValue =
# ARMTest: [<__main__.SentinelPricing object at 0x0000016EB2B29A00>]
# TierTest: []
# currentTierType = <class 'str'>, currentTierValue = 100
# previousTierType = <class 'str'>, previousTierValue = Pay-as-you-go
# ARMTest: [<__main__.SentinelPricing object at 0x0000016EB2C57280>, <__main__.SentinelPricing object at 0x0000016EB2C68B20>, <__main__.SentinelPricing object at 0x0000016EB2BB8F10>, <__main__.SentinelPricing object at 0x0000016EB2C68910>, <__main__.SentinelPricing object at 0x0000016EB2B29970>, <__main__.SentinelPricing object at 0x0000016EB2B24EE0>, <__main__.SentinelPricing object at 0x0000016EB2B014C0>, <__main__.SentinelPricing object at 0x0000016EB2B78160>]
# TierTest: [<__main__.SentinelPricing object at 0x0000016EB2B29A00>, <__main__.SentinelPricing object at 0x0000016EB2BB89D0>, <__main__.SentinelPricing object at 0x0000016EB2C281F0>, <__main__.SentinelPricing object at 0x0000016EB2B78F10>, <__main__.SentinelPricing object at 0x0000016EB2C68700>, <__main__.SentinelPricing object at 0x0000016EB2BCE070>, <__main__.SentinelPricing object at 0x0000016EB2BB89A0>, <__main__.SentinelPricing object at 0x0000016EB2B22C10>, <__main__.SentinelPricing object at 0x0000016EB2B78BE0>, <__main__.SentinelPricing object at 0x0000016EB2B29BB0>, <__main__.SentinelPricing object at 0x0000016EB2C0BAF0>, <__main__.SentinelPricing object at 0x0000016EB2C68160>, <__main__.SentinelPricing object at 0x0000016EB2B29E80>, <__main__.SentinelPricing object at 0x0000016EB2B66BE0>, <__main__.SentinelPricing object at 0x0000016EB2BB8640>, <__main__.SentinelPricing object at 0x0000016EB2B78F40>, <__main__.SentinelPricing object at 0x0000016EB2BB8760>, <__main__.SentinelPricing object at 0x0000016EB2BB8DC0>, <__main__.SentinelPricing object at 0x0000016EB2BCE8B0>, <__main__.SentinelPricing object at 0x0000016EB2BB8490>, <__main__.SentinelPricing object at 0x0000016EB2B01250>, <__main__.SentinelPricing object at 0x0000016EB2B24D30>, <__main__.SentinelPricing object at 0x0000016EA2184280>, <__main__.SentinelPricing object at 0x0000016EB2B78AC0>, <__main__.SentinelPricing object at 0x0000016EB2BE8220>, <__main__.SentinelPricing object at 0x0000016EB2BE8460>, <__main__.SentinelPricing object at 0x0000016EB2C680D0>, <__main__.SentinelPricing object at 0x0000016EB2BB8850>, <__main__.SentinelPricing object at 0x0000016EB2B24670>, <__main__.SentinelPricing object at 0x0000016EB2BB8310>, <__main__.SentinelPricing object at 0x0000016EB2B01A00>, <__main__.SentinelPricing object at 0x0000016EB2C570D0>, <__main__.SentinelPricing object at 0x0000016EB2B24BE0>, <__main__.SentinelPricing object at 0x0000016EB2BB8220>, <__main__.SentinelPricing object at 0x0000016EB2BB8A60>, <__main__.SentinelPricing object at 0x0000016EB2B29E50>, <__main__.SentinelPricing object at 0x0000016EB2BCEBE0>, <__main__.SentinelPricing object at 0x0000016EB2BE8070>, <__main__.SentinelPricing object at 0x0000016EB2C284F0>, <__main__.SentinelPricing object at 0x0000016EB2C681C0>, <__main__.SentinelPricing object at 0x0000016EB2B66BB0>, <__main__.SentinelPricing object at 0x0000016EB2BE8EB0>, <__main__.SentinelPricing object at 0x0000016EB2B018B0>, <__main__.SentinelPricing object at 0x0000016EB2C28FA0>, <__main__.SentinelPricing object at 0x0000016EB2BCE880>, <__main__.SentinelPricing object at 0x0000016EB2C57310>, <__main__.SentinelPricing object at 0x0000016EB2B29D00>, <__main__.SentinelPricing object at 0x0000016EB2BB8F70>, <__main__.SentinelPricing object at 0x0000016EB2C0B490>, <__main__.SentinelPricing object at 0x0000016EB2B29AF0>, <__main__.SentinelPricing object at 0x0000016EB2B29880>]
# currentTierType = <class 'str'>, currentTierValue = 200
# previousTierType = <class 'int'>, previousTierValue = 100
# ARMTest: [<__main__.SentinelPricing object at 0x0000016EB2C57280>, <__main__.SentinelPricing object at 0x0000016EB2C68B20>, <__main__.SentinelPricing object at 0x0000016EB2BB8F10>, <__main__.SentinelPricing object at 0x0000016EB2C68910>, <__main__.SentinelPricing object at 0x0000016EB2B29970>, <__main__.SentinelPricing object at 0x0000016EB2B24EE0>, <__main__.SentinelPricing object at 0x0000016EB2B014C0>, <__main__.SentinelPricing object at 0x0000016EB2B78160>]
# TierTest: []
